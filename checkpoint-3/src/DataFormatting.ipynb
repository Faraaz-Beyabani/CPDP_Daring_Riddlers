# %%
import re
import csv
import json

# %%
data = csv.reader(open('trr_per_district_per_year_.csv'))

# %%
headers = next(data)

# %%
geo_json = {
    'type': 'FeatureCollection',
    'features': []
}
trr_data  = {}
for line in data:
#     district = line[0]
#     if district not in geo_json['features']:
#         coordinate_data = json.loads(line[3])
#         coordinate_data['properties'] = line[0]
#         geo_json['features'].append(coordinate_data)
    if not line:
        continue
    year = int(line[1])
    if year not in trr_data:
        trr_data[year] = {}
    trr_data[year][line[0]] = float(line[2])

# %%
geo_json['features'][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-6e253abd5aca> in <module>
# ----> 1 geo_json['features'][0]
#
# IndexError: list index out of range

# %%
open('district_polygons.geojson', 'w').write(json.dumps(geo_json))

# %%
open('trr_per_capita.json', 'w').write(json.dumps(trr_data))

# %%
trr_data
# Out:
# {2016: {'17th': 1.98,
#   '22nd': 2.07,
#   '5th': 3.6,
#   '24th': 3.42,
#   '16th': 1.71,
#   '8th': 3.42,
#   '19th': 2.79,
#   '25th': 4.68,
#   '20th': 2.07,
#   '18th': 4.68,
#   '12th': 3.6,
#   '11th': 11.97,
#   '3rd': 5.85,
#   '14th': 1.71,
#   '4th': 9.27,
#   '6th': 7.74,
#   '10th': 4.86,
#   '1st': 4.68,
#   '9th': 3.78,
#   '2nd': 2.43,
#   '7th': 6.84,
#   '15th': 6.75},
#  2015: {'17th': 1.3,
#   '22nd': 1.82,
#   '5th': 4.62,
#   '24th': 3.18,
#   '16th': 2.25,
#   '8th': 4.45,
#   '19th': 3.52,
#   '25th': 6.27,
#   '20th': 1.28,
#   '18th': 3.67,
#   '12th': 2.59,
#   '11th': 11.56,
#   '3rd': 4.64,
#   '14th': 2.36,
#   '4th': 7.6,
#   '6th': 7.8,
#   '10th': 4.49,
#   '1st': 3.67,
#   '9th': 4.93,
#   '2nd': 1.19,
#   '7th': 8.55,
#   '15th': 7.6},
#  2014: {'17th': 1.57,
#   '31st': 0.04,
#   '22nd': 2.59,
#   '5th': 4.75,
#   '24th': 2.8,
#   '16th': 2.06,
#   '8th': 5.31,
#   '19th': 4.3,
#   '25th': 5.73,
#   '20th': 1.23,
#   '18th': 3.95,
#   '12th': 2.28,
#   '11th': 12.51,
#   '3rd': 5.86,
#   '14th': 2.36,
#   '4th': 5.72,
#   '6th': 7.25,
#   '10th': 5.77,
#   '1st': 2.82,
#   '9th': 4.27,
#   '2nd': 1.78,
#   '7th': 7.37,
#   '15th': 7.2},
#  2013: {'17th': 1.9,
#   '31st': 0.09,
#   '22nd': 2.44,
#   '5th': 4.23,
#   '24th': 2.29,
#   '16th': 1.87,
#   '8th': 5.42,
#   '19th': 4.69,
#   '25th': 4.55,
#   '20th': 1.65,
#   '18th': 5.0,
#   '12th': 3.17,
#   '11th': 10.06,
#   '3rd': 4.39,
#   '14th': 2.76,
#   '4th': 5.69,
#   '6th': 8.41,
#   '10th': 5.83,
#   '1st': 3.06,
#   '9th': 4.94,
#   '2nd': 2.01,
#   '7th': 8.04,
#   '15th': 7.02},
#  2012: {'17th': 1.58,
#   '31st': 0.03,
#   '22nd': 2.57,
#   '5th': 5.43,
#   '24th': 2.89,
#   '16th': 1.44,
#   '8th': 6.39,
#   '19th': 4.18,
#   '25th': 5.55,
#   '20th': 1.87,
#   '18th': 4.57,
#   '12th': 3.8,
#   '11th': 9.28,
#   '3rd': 5.26,
#   '14th': 2.86,
#   '4th': 6.01,
#   '6th': 7.67,
#   '10th': 3.89,
#   '1st': 2.65,
#   '9th': 5.43,
#   '2nd': 1.68,
#   '7th': 7.62,
#   '15th': 6.92},
#  2011: {'17th': 1.95,
#   '31st': 0.03,
#   '22nd': 2.63,
#   '5th': 4.57,
#   '24th': 2.85,
#   '16th': 2.08,
#   '8th': 5.92,
#   '19th': 3.77,
#   '25th': 6.28,
#   '20th': 1.67,
#   '18th': 4.49,
#   '12th': 3.53,
#   '11th': 11.35,
#   '3rd': 4.71,
#   '14th': 2.94,
#   '4th': 5.56,
#   '6th': 7.8,
#   '10th': 4.03,
#   '1st': 2.76,
#   '9th': 5.17,
#   '2nd': 2.53,
#   '7th': 5.44,
#   '15th': 7.53},
#  2010: {'17th': 2.04,
#   '31st': 0.03,
#   '22nd': 3.47,
#   '5th': 4.76,
#   '24th': 3.61,
#   '16th': 2.2,
#   '8th': 4.65,
#   '19th': 3.88,
#   '25th': 5.44,
#   '20th': 1.48,
#   '18th': 5.02,
#   '12th': 4.05,
#   '11th': 10.7,
#   '3rd': 4.67,
#   '14th': 3.06,
#   '4th': 3.74,
#   '6th': 6.3,
#   '10th': 5.62,
#   '1st': 3.3,
#   '9th': 5.05,
#   '2nd': 2.58,
#   '7th': 6.53,
#   '15th': 7.35},
#  2009: {'17th': 2.41,
#   '31st': 0.02,
#   '22nd': 2.47,
#   '5th': 5.44,
#   '24th': 3.5,
#   '16th': 1.78,
#   '8th': 5.82,
#   '19th': 3.61,
#   '25th': 6.62,
#   '20th': 1.34,
#   '18th': 4.51,
#   '12th': 3.61,
#   '11th': 10.44,
#   '3rd': 4.17,
#   '14th': 3.68,
#   '4th': 4.72,
#   '6th': 6.41,
#   '10th': 5.16,
#   '1st': 2.96,
#   '9th': 6.24,
#   '2nd': 2.86,
#   '7th': 5.16,
#   '15th': 6.69},
#  2008: {'17th': 1.99,
#   '31st': 0.07,
#   '22nd': 2.56,
#   '5th': 4.15,
#   '24th': 3.74,
#   '16th': 1.71,
#   '8th': 6.21,
#   '19th': 3.79,
#   '25th': 6.06,
#   '20th': 1.75,
#   '18th': 4.4,
#   '12th': 5.87,
#   '11th': 9.1,
#   '3rd': 5.25,
#   '14th': 3.27,
#   '4th': 4.66,
#   '6th': 6.46,
#   '10th': 5.58,
#   '1st': 2.89,
#   '9th': 5.83,
#   '2nd': 3.27,
#   '7th': 5.7,
#   '15th': 5.07},
#  2007: {'17th': 2.27,
#   '31st': 0.02,
#   '22nd': 2.09,
#   '5th': 4.26,
#   '24th': 2.92,
#   '16th': 2.33,
#   '8th': 4.85,
#   '19th': 4.48,
#   '25th': 4.85,
#   '20th': 1.85,
#   '18th': 5.75,
#   '12th': 4.62,
#   '11th': 10.5,
#   '3rd': 4.93,
#   '14th': 3.14,
#   '4th': 4.14,
#   '6th': 7.92,
#   '10th': 5.19,
#   '1st': 2.9,
#   '9th': 5.71,
#   '2nd': 3.98,
#   '7th': 5.47,
#   '15th': 5.17},
#  2006: {'17th': 2.43,
#   '22nd': 2.55,
#   '5th': 3.75,
#   '24th': 3.3,
#   '16th': 2.47,
#   '8th': 5.23,
#   '19th': 4.2,
#   '25th': 4.68,
#   '20th': 1.36,
#   '18th': 6.28,
#   '12th': 5.13,
#   '11th': 12.42,
#   '3rd': 4.68,
#   '14th': 3.62,
#   '4th': 4.47,
#   '6th': 4.82,
#   '10th': 4.57,
#   '1st': 3.48,
#   '9th': 5.79,
#   '2nd': 3.34,
#   '7th': 5.6,
#   '15th': 5.44},
#  2005: {'17th': 2.38,
#   '31st': 0.04,
#   '22nd': 2.03,
#   '5th': 4.37,
#   '24th': 3.32,
#   '16th': 2.26,
#   '8th': 4.76,
#   '19th': 5.26,
#   '25th': 5.59,
#   '20th': 2.22,
#   '18th': 5.13,
#   '12th': 4.14,
#   '11th': 11.66,
#   '3rd': 4.29,
#   '14th': 3.46,
#   '4th': 4.74,
#   '6th': 4.36,
#   '10th': 5.33,
#   '1st': 3.77,
#   '9th': 4.53,
#   '2nd': 3.56,
#   '7th': 7.5,
#   '15th': 4.97},
#  2004: {'17th': 2.35,
#   '31st': 0.02,
#   '22nd': 1.96,
#   '5th': 4.52,
#   '24th': 3.02,
#   '16th': 2.76,
#   '8th': 4.28,
#   '19th': 4.65,
#   '25th': 5.15,
#   '20th': 1.78,
#   '18th': 5.13,
#   '12th': 4.41,
#   '11th': 12.19,
#   '3rd': 5.24,
#   '14th': 3.63,
#   '4th': 3.8,
#   '6th': 4.82,
#   '10th': 5.17,
#   '1st': 2.91,
#   '9th': 4.98,
#   '2nd': 4.28,
#   '7th': 6.91,
#   '15th': 5.63}}
